# %%
class Roman:
    
    def __init__(self, num):
        
        if isinstance(num, str):
            self.roman = num
            self.arab = 0
        
        if isinstance(num, int):
            self.arab = num
            self.roman = rom2ar(num)

# %%
romaiNum = Roman(3458)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-185da5a701a3> in <module>
# ----> 1 romaiNum = Roman(3458)
#
# <ipython-input-1-59c8b2319600> in __init__(self, num)
#       9         if isinstance(num, int):
#      10             self.arab = num
# ---> 11             self.roman = rom2ar(num)
#
# NameError: name 'rom2ar' is not defined
