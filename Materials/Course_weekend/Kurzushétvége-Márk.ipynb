# %%
import glob
import json

# %%
message_files = sorted(glob.glob("*-msg.json"))

# %%
message_files
# Out:
# ['2010-msg.json',
#  '2011-msg.json',
#  '2012-msg.json',
#  '2013-msg.json',
#  '2014-msg.json',
#  '2015-msg.json',
#  '2016-msg.json',
#  '2017-msg.json',
#  '2018-msg.json',
#  '2019-msg.json',
#  '2020-msg.json']

# %%
def get_data(path):

    with open(path, "r") as fp:
        file = json.load(fp)

    return file

# %%
list_of_dicts_2010 = get_data(message_files[0])

# %%
list_of_dicts_2010[0]
# Out:
# {'index': 1797,
#  'sender_name': 'Colin Firth',
#  'timestamp_ms': 1289492566000,
#  'type': 'Generic',
#  'thread_path': 622,
#  'thread_type': 'Regular',
#  'reactions': [],
#  'sticker': None,
#  'ip': None,
#  'photos': 0,
#  'users': [],
#  'gifs': 0,
#  'videos': 0,
#  'content_l': 8,
#  'datetime': '2010-11-11T17:22:46.000Z',
#  'year': 2010,
#  'month': 11,
#  'day': 11,
#  'hour': 17,
#  'minute': 22}

# %%
list_of_dicts_2018 = get_data(message_files[8])

# %%
list_of_dicts_2018
# Out:
# [{'index': 8224,
#   'sender_name': 'King Kong',
#   'timestamp_ms': 1528384770419,
#   'type': 'Generic',
#   'thread_path': 494,
#   'thread_type': 'RegularGroup',
#   'reactions': [],
#   'sticker': None,
#   'ip': None,
#   'photos': 0,
#   'users': [],
#   'gifs': 0,
#   'videos': 0,
#   'content_l': 21,
#   'datetime': '2018-06-07T17:19:30.419Z',
#   'year': 2018,
#   'month': 6,
#   'day': 7,
#   'hour': 17,
#   'minute': 19},
#  {'index': 4508,
#   'sender_name': 'Colin Firth',
#   'timestamp_ms': 1518782979603,
#   'type': 'Generic',
#   'thread_path': 502,
#   'thread_type': 'Regular',
#   'reactions': [],
#   'sticker': None,
#   'ip': None,
#   'photos': 0,
#   'users': [],
#   'gifs': 0,
#   'videos': 0,
#   'content_l': 43,
#   'datetime': '2018-02-16T13:09:39.603Z',
#   'year': 2018,
#   'month': 2,
#   'day': 16,
#   'hour': 13,
#   'minute': 9},
#  {'index': 155,
#   'sender_name': 'Don Ameche',
#   'timestamp_ms': 1543439754721,
#   'type': 'Generic',
# ...

# %%
seq = []
#seq = {}

for i in list_of_dicts_2018:
    if i["type"] == "Subscribe" and i["month"] > 5:
        #seq[i["thread_path"]] = (len(i["users"]))
        seq.append(len(i["users"]))
        seq.append(i["thread_path"])
print(seq)
# Out:
# [1, 356, 1, 798, 1, 494, 1, 259, 1, 554, 20, 494, 2, 285, 1, 356, 1, 790, 1, 494, 1, 712, 1, 552, 1, 554, 1, 790, 1, 356, 1, 494, 1, 494, 1, 798, 1, 494, 1, 741, 1, 763, 1, 269, 1, 147, 0, 557, 1, 606, 1, 498, 1, 660, 1, 782, 1, 606, 6, 306, 1, 790, 5, 306, 1, 713, 1, 371, 1, 646, 1, 494, 2, 782, 1, 147, 1, 371, 1, 712, 1, 798, 1, 790, 1, 713, 4, 504, 1, 147]

# %%
list_of_dicts_2010 = get_data(message_files[0])
list_of_dicts_2011 = get_data(message_files[1])
list_of_dicts_2012 = get_data(message_files[2])
list_of_dicts_2013 = get_data(message_files[3])
list_of_dicts_2014 = get_data(message_files[4])
list_of_dicts_2015 = get_data(message_files[5])
list_of_dicts_2016 = get_data(message_files[6])
list_of_dicts_2017 = get_data(message_files[7])
list_of_dicts_2018 = get_data(message_files[8])
list_of_dicts_2019 = get_data(message_files[9])
list_of_dicts_2020 = get_data(message_files[10])

lista = [list_of_dicts_2017,list_of_dicts_2018,list_of_dicts_2019,list_of_dicts_2020]

# %%
#Ki unscubsribeolt legtöbbször a jeszk momentsből?
seq = []
for i in list_of_dicts_2017:
    if i['type'] == 'Unsubscribe' and i['thread_path'] == 494:
        #seq[i["thread_path"]] = (len(i["users"]))
        seq.append(i['users'])
        
for i in list_of_dicts_2018:
    if i['type'] == 'Unsubscribe' and i['thread_path'] == 494:
        #seq[i["thread_path"]] = (len(i["users"]))
        seq.append(i['users'])
        
for i in list_of_dicts_2019:
    if i['type'] == 'Unsubscribe' and i['thread_path'] == 494:
        #seq[i["thread_path"]] = (len(i["users"]))
        seq.append(i['users'])
        
for i in list_of_dicts_2020:
    if i['type'] == 'Unsubscribe' and i['thread_path'] == 494:
        #seq[i["thread_path"]] = (len(i["users"]))
        seq.append(i['users'])
jo = []
        
for i in seq:
    for k in i:
        jo.append(k)

my_dict = {i:jo.count(i) for i in jo}
        
print(my_dict)
# Out:
# {'Rachel McAdams': 1, 'Mahershala Ali': 3, 'Don Ameche': 1, 'Gwyneth Paltrow': 1, 'Ed Harris': 2, 'Fay Bainter': 1, 'George Lucas': 1, 'Saoirse Ronan': 1, 'Scarlett Johansson': 1, 'Casey Affleck': 1, 'Grace Kelly': 1, 'Jennifer Hudson': 1, 'Ronald McDonald': 1, 'Loretta Young': 1, 'Mickey Rourke': 2, 'Julia Roberts': 2, 'Alice Brady': 1, 'Denzel Washington': 2, 'Lee Grant': 1, 'Ed Sheeran': 1, 'Chris Cooper': 3, 'Harvey Keitel': 1, 'Steve Carell': 1, 'Mercedes Ruehl': 1, 'Hawkeye Pierce ': 1, 'Maggie Gyllenhaal': 1, 'Dorothy Malone': 2, 'George Arliss': 1, 'Cliff Robertson': 1, 'Joan Fontaine': 1, 'Hattie McDaniel': 1, 'Felicity Jones': 2, 'Jack Albertson': 1, 'John Malkovich': 3, 'James Cagney': 1, 'Massimo Troisi': 1, 'Paul Newman': 1, 'Jack Palance': 1, 'Julianne Moore': 1, 'The Weeknd': 1, 'Joanne Woodward': 1, 'Ginger Rogers': 1, 'Michelle Pfeiffer': 1, 'Maggie Smith': 1, 'Ben Johnson': 1, "Mo'Nique": 1, 'Anna Paquin': 1, 'Rosie Perez': 1, 'Broderick Crawford': 1}

# %%
seq = []

for i in list_of_dicts_2010:
        
        seq.append(i['sender_name'])

for i in list_of_dicts_2011:
        
        seq.append(i['sender_name'])
        
for i in list_of_dicts_2012:
        
        seq.append(i['sender_name'])
        
for i in list_of_dicts_2013:
        
        seq.append(i['sender_name'])

for i in list_of_dicts_2014:
        
        seq.append(i['sender_name'])
        
for i in list_of_dicts_2015:
        
        seq.append(i['sender_name'])
        
for i in list_of_dicts_2016:
        
        seq.append(i['sender_name'])
        
for i in list_of_dicts_2017:
        
        seq.append(i['sender_name'])        

for i in list_of_dicts_2018:
        
        seq.append(i['sender_name'])
        
for i in list_of_dicts_2019:        
        
        seq.append(i['sender_name'])
        
for i in list_of_dicts_2020:
        
        seq.append(i['sender_name'])
        



print(seq)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
seq = []
#seq = {}

for i in list_of_dicts_2018:
    if i["type"] == "Subscribe" and i["month"] > 5:
        #seq[i["thread_path"]] = (len(i["users"]))
        seq.append(len(i["users"]))
        seq.append(i["thread_path"])
print(seq)
# Out:
# [1, 356, 1, 798, 1, 494, 1, 259, 1, 554, 20, 494, 2, 285, 1, 356, 1, 790, 1, 494, 1, 712, 1, 552, 1, 554, 1, 790, 1, 356, 1, 494, 1, 494, 1, 798, 1, 494, 1, 741, 1, 763, 1, 269, 1, 147, 0, 557, 1, 606, 1, 498, 1, 660, 1, 782, 1, 606, 6, 306, 1, 790, 5, 306, 1, 713, 1, 371, 1, 646, 1, 494, 2, 782, 1, 147, 1, 371, 1, 712, 1, 798, 1, 790, 1, 713, 4, 504, 1, 147]

# %%
valami = []
for i in list_of_dicts_2019:
    if i['month'] == 2 and i['day'] == 12 and i['type'] == 'Subscribe' and i['sender_name'] == 'Liza Minnelli':
        valami.append(i)
print (valami)
# Out:
# [{'index': 49, 'sender_name': 'Liza Minnelli', 'timestamp_ms': 1549962742723, 'type': 'Subscribe', 'thread_path': 478, 'thread_type': 'RegularGroup', 'reactions': [], 'sticker': None, 'ip': None, 'photos': 0, 'users': ['Shohreh Aghdashloo'], 'gifs': 0, 'videos': 0, 'content_l': 45, 'datetime': '2019-02-12T10:12:22.723Z', 'year': 2019, 'month': 2, 'day': 12, 'hour': 10, 'minute': 12}, {'index': 48, 'sender_name': 'Liza Minnelli', 'timestamp_ms': 1549963252976, 'type': 'Subscribe', 'thread_path': 478, 'thread_type': 'RegularGroup', 'reactions': [], 'sticker': None, 'ip': None, 'photos': 0, 'users': ['John Malkovich'], 'gifs': 0, 'videos': 0, 'content_l': 42, 'datetime': '2019-02-12T10:20:52.976Z', 'year': 2019, 'month': 2, 'day': 12, 'hour': 10, 'minute': 20}]

# %%
valami2 = []
for i in list_of_dicts_2019:
    if i['month'] == 10 and i['day'] == 26 and i['type'] == 'Subscribe':
        valami2.append(i)
print (valami2)
# Out:
# [{'index': 2227, 'sender_name': 'Liza Minnelli', 'timestamp_ms': 1572102747852, 'type': 'Subscribe', 'thread_path': 797, 'thread_type': 'RegularGroup', 'reactions': [], 'sticker': None, 'ip': None, 'photos': 0, 'users': ['Don Cheadle', 'Ray Milland'], 'gifs': 0, 'videos': 0, 'content_l': 62, 'datetime': '2019-10-26T17:12:27.852Z', 'year': 2019, 'month': 10, 'day': 26, 'hour': 17, 'minute': 12}]

# %%
#Ki írta a legkevesebb üzenetet a 2019-es db-chatbe?
uzenet = []
for i in list_of_dicts_2019:
    if i["type"] == "Generic" and i["thread_path"] == 797:
        uzenet.append(i["sender_name"])

for i in list_of_dicts_2020:
    if i["type"] == "Generic" and i["thread_path"] == 797:
        uzenet.append(i["sender_name"])

teljes = {i:uzenet.count(i) for i in uzenet}

print (teljes)
#megoldas: Don Cheadle
# Out:
# {'Katy Perry': 941, 'Liza Minnelli': 2561, 'Al Pacino': 1786, 'Sylvester Stallone': 278, 'Christopher Walken': 951, 'Kate Winslet': 729, 'Adam Driver': 1513, 'Atticus Finch': 41, 'Colin Firth': 513, 'Don Cheadle': 35, 'Adriana Barraza': 106, 'Glenn Close': 99, 'Ray Milland': 43}

# %%
reakcio1 = []
reakcio2 = []

for i in list_of_dicts_2017:
    if i['thread_path'] == 494 and i['type'] == 'Generic' or 'Share':
        reakcio1.append(i['thread_path'])
        reakcio2.append(i['reactions'])
reakcio3 = []        
for i in reakcio2:
    reakcio3.append(len(i))

for i in list_of_dicts_2018:
    if i['thread_path'] == 494 and i['type'] == 'Generic' or 'Share':
        reakcio1.append(i['thread_path'])
        reakcio2.append(i['reactions'])
reakcio3 = []        
for i in reakcio2:
    reakcio3.append(len(i))
    
for i in list_of_dicts_2019:
    if i['thread_path'] == 494 and i['type'] == 'Generic' or 'Share':
        reakcio1.append(i['thread_path'])
        reakcio2.append(i['reactions'])
reakcio3 = []        
for i in reakcio2:
    reakcio3.append(len(i))
    
for i in list_of_dicts_2020:
    if i['thread_path'] == 494 and i['type'] == 'Generic' or 'Share':
        reakcio1.append(i['thread_path'])
        reakcio2.append(i['reactions'])

reakcio3 = []        
for i in reakcio2:
    reakcio3.append(len(i))

csicska = []
for i in range (183322):
    csicska.append(reakcio1[i])
    csicska.append(reakcio3[i])
    
teljes0 = {reakcio1[i]: reakcio1.count(i) for i in range(0, len(reakcio1), 2)}
print (teljes0)
# Out:
# {11: 0, 858: 0, 857: 0, 709: 0, 757: 323, 339: 0, 859: 0, 524: 0, 558: 0, 559: 0, 146: 0, 472: 0, 609: 0, 103: 0, 502: 0, 494: 0, 18: 0, 733: 0, 126: 0, 4: 0, 721: 0, 769: 0, 742: 0, 870: 0, 108: 0, 353: 0, 850: 0, 682: 0, 839: 0, 297: 0, 767: 0, 659: 0, 633: 0, 667: 0, 652: 0, 595: 0, 636: 0, 164: 0, 798: 0, 582: 0, 379: 0, 17: 0, 424: 0, 178: 0, 122: 0, 109: 0, 876: 0, 144: 0, 645: 0, 196: 0, 49: 0, 288: 0, 449: 0, 56: 0, 824: 0, 59: 0, 744: 0, 66: 0, 647: 0, 719: 0, 760: 0, 135: 0, 823: 0, 92: 0, 579: 0, 620: 0, 386: 0, 142: 0, 340: 0, 215: 0, 716: 0, 34: 0, 729: 0, 686: 0, 13: 0, 415: 0, 425: 0, 124: 0, 363: 0, 710: 0, 432: 0, 880: 0, 722: 0, 154: 0, 376: 0, 497: 0, 510: 0, 651: 0, 278: 0, 860: 0, 61: 0, 90: 0, 336: 0, 720: 0, 413: 0, 843: 0, 75: 0, 777: 0, 418: 0, 465: 0, 855: 0, 130: 0, 177: 0, 397: 0, 538: 0, 284: 0, 851: 0, 427: 0, 89: 0, 150: 0, 366: 0, 500: 0, 57: 0, 572: 0, 121: 0, 271: 0, 848: 0, 105: 0, 53: 0, 845: 0, 527: 0, 335: 0, 21: 0, 280: 0, 342: 0, 419: 0, 814: 0
# ...

# %%
ures1 = []

for i in list_of_dicts_2010:
    ures1.append(i['timestamp_ms'])
    
print (sorted(ures1))
# Out:
# [1269556341000, 1281087355000, 1284905757000, 1284969721000, 1284971204000, 1284989844000, 1285003398000, 1285508582000, 1285510848000, 1285524443000, 1286824830000, 1286894795000, 1286900235000, 1287249339000, 1287321679000, 1287580612000, 1287584302000, 1287590316000, 1287591940000, 1287594955000, 1287594964000, 1287595289000, 1287828862000, 1287842432000, 1287848654000, 1287848720000, 1288617754000, 1289127182000, 1289130904000, 1289131850000, 1289132035000, 1289132090000, 1289488005000, 1289492135000, 1289492430000, 1289492566000, 1289991568000, 1290004157000, 1290005602000, 1290005620000, 1290005656000, 1290006727000, 1290092775000, 1290334470000, 1290356556000, 1290366696000, 1290442922000, 1290522692000, 1290523779000, 1290529554000, 1290530537000, 1290535947000, 1290540552000, 1290616558000, 1290622702000, 1290622824000, 1290623412000, 1290626083000, 1290626711000, 1290626755000, 1290627507000, 1290627856000, 1290632556000, 1290632618000, 1290677990000, 1290678027000, 1290703
# ...

# %%
ures2 = []

for i in list_of_dicts_2017:
    if (i['thread_path']) == 494:
        ures2.append(i['timestamp_ms'])
    
print (sorted(ures2))
# Out:
# [1508190876228, 1508190885907, 1508191105184, 1508191114591, 1508191127002, 1508191128750, 1508191140524, 1508191142995, 1508191165104, 1508191167836, 1508191169318, 1508191186807, 1508191208458, 1508191216360, 1508191245661, 1508191251177, 1508191259615, 1508191264798, 1508191266771, 1508191266915, 1508191271677, 1508191273763, 1508191274429, 1508191276163, 1508191283168, 1508191285387, 1508191289886, 1508191294259, 1508191305413, 1508191322473, 1508191329515, 1508191372308, 1508191380295, 1508191387262, 1508191415808, 1508191426932, 1508191438254, 1508191467796, 1508191521819, 1508191522045, 1508191523715, 1508191534079, 1508191534783, 1508191541752, 1508191549220, 1508191556351, 1508191557018, 1508191568878, 1508191577893, 1508191617082, 1508191628645, 1508191644091, 1508191645432, 1508191662209, 1508191671705, 1508191681728, 1508191696842, 1508191702719, 1508191710503, 1508191711316, 1508191716622, 1508191727603, 1508191728847, 1508191736399, 1508191747718, 1508191754172, 1508191
# ...

# %%
ures3 = []
for i in list_of_dicts_2019:
    if (i['month']) == 3 and (i['day'] == 10):
        ures3.append(i['timestamp_ms'])
print (ures3)
# Out:
# [1552219822588, 1552232775413, 1552218472031, 1552243573072, 1552254238034, 1552245472499, 1552222663573, 1552218023039, 1552205003437, 1552225644334, 1552222559826, 1552222922558, 1552224718122, 1552244226718, 1552243509649, 1552230098891, 1552224940963, 1552222946304, 1552243480151, 1552218219549, 1552225531945, 1552244470334, 1552225587567, 1552223464962, 1552243459831, 1552222727364, 1552225062718, 1552218338675, 1552233561184, 1552218245819, 1552222656901, 1552233565039, 1552226643761, 1552224845094, 1552240640609, 1552225464208, 1552225387647, 1552244334441, 1552222646164, 1552223472036, 1552245056869, 1552237070619, 1552225491746, 1552224807086, 1552225036546, 1552252909701, 1552243495098, 1552224674957, 1552225403699, 1552223478676, 1552206447737, 1552225920733, 1552249394547, 1552257760914, 1552240676407, 1552257669041, 1552218143668, 1552218354586, 1552218228113, 1552241044644, 1552241215471, 1552222676473, 1552219464205, 1552223324520, 1552225762848, 1552225715281, 1552225
# ...

# %%
ures4 = []
for
